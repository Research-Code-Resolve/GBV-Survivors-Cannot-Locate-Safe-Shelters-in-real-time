# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('gbv-dataset.csv') # Load the dataset into a pandas DataFrame

# %%
df.head() # Display the first few rows of the dataset
# Out:
#   Interview_ID  organization                               Role   \
# 0         SW01  Malawi Police  Victim Support Unit Social Worker
# 1         SW01  Malawi Police  Victim Support Unit Social Worker
# 2         SW01  Malawi Police  Victim Support Unit Social Worker
# 3         SW01  Malawi Police  Victim Support Unit Social Worker
# 4         SW01  Malawi Police  Victim Support Unit Social Worker
#
#   Research_Question            Theme                    Subtheme  \
# 0               RQ2  Access Pathways         Victim Support Unit
# 1               RQ1         Barriers              Fear of Police
# 2               RQ1         Barriers  Fear of Perpetrator Arrest
# 3               RQ1         Barriers                Gender Norms
# 4               RQ4       Challenges           Capacity Building
#
#               Initial_Code                                           Evidence  \
# 0  Entry point to services  Survivors primarily access support by reportin...
# ...

# %%
df.info() # Display information about the dataset, including column names, data types, and non-null counts
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Interview_ID       135 non-null    str
#  1   organization       135 non-null    str
#  2   Role               135 non-null    str
#  3   Research_Question  135 non-null    str
#  4   Theme              135 non-null    str
#  5   Subtheme           135 non-null    str
#  6   Initial_Code       135 non-null    str
#  7   Evidence           135 non-null    str
#  8   Quote              135 non-null    str
#  9   Recommendation     135 non-null    str
# dtypes: str(10)
# memory usage: 10.7 KB

# %%
df.shape # Display the number of rows and columns in the dataset
# Out:
# (135, 10)

# %%
df.isnull().sum() # Check for missing values in the dataset
# Out:
# Interview_ID         0
# organization         0
# Role                 0
# Research_Question    0
# Theme                0
# Subtheme             0
# Initial_Code         0
# Evidence             0
# Quote                0
# Recommendation       0
# dtype: int64

# %%
df.describe(include='all')   # Display summary statistics for numerical columns in the dataset
# Out:
#        Interview_ID  organization           Role  Research_Question  \
# count           135            135            135               135
# unique            7              6              4                 5
# top            SW03  Malawi Police  Social Worker               RQ2
# freq             27             31             90                49
#
#                   Theme             Subtheme             Initial_Code  \
# count               135                  135                      135
# unique                5                  101                      121
# top     Access Pathways  Community Awareness  Temporary accommodation
# freq                 49                    6                        3
#
#                                                  Evidence  \
# count                                                 135
# unique                                                135
# top     Survivors primarily access support by reportin...
# ...

# %%
rq_counts = df["Research_Question"].value_counts()

rq_counts.plot(kind="bar")
#This shows which research questions generated the richest data.
# Out:
# <Axes: xlabel='Research_Question'>

# %%
theme_counts = df["Theme"].value_counts()

theme_counts.plot(kind="bar")

#Which themes appeared the most?
# Out:
# <Axes: xlabel='Theme'>

# %%
subtheme = df["Subtheme"].value_counts()

subtheme.plot(kind="barh")
# Out:
# <Axes: ylabel='Subtheme'>

# %%
pd.crosstab(df["Interview_ID"],
            df["Theme"])
# Out:
# Theme         Access Pathways  Barriers  Challenges  Opportunities  \
# Interview_ID
# SW01                        1         3           3              2
# SW02                        8         4           2              4
# SW03                        8         5           8              2
# SW04                        7         5           3              5
# SW05                       10         2           4              2
# SW06                        9         3           4              3
# SW07                        6         0           3              5
#
# Theme         Survivor Needs
# Interview_ID
# SW01                       4
# SW02                       0
# SW03                       4
# SW04                       0
# SW05                       3
# SW06                       3
# SW07                       0

# %%
table = pd.crosstab(df["Interview_ID"],
                    df["Theme"])

table.plot(kind="bar",
           stacked=True)

plt.show()

#what themes the paricipants discussed the most, and how many participants discussed each theme

# %%
pd.crosstab(df["Research_Question"],
            df["Theme"])

# This creates a cross-tabulation of the research questions and themes
# Out:
# Theme              Access Pathways  Barriers  Challenges  Opportunities  \
# Research_Question
# RQ1                              0        22           0              0
# RQ2                             49         0           0              0
# RQ3                              0         0           0              0
# RQ4                              0         0          27              0
# RQ5                              0         0           0             23
#
# Theme              Survivor Needs
# Research_Question
# RQ1                             0
# RQ2                             0
# RQ3                            14
# RQ4                             0
# RQ5                             0

# %%
heatmap_data = pd.crosstab(df["Research_Question"],
                           df["Theme"])
# This creates a cross-tabulation of the research questions and themes

# %%
df["Initial_Code"].value_counts().head(20) # This shows the most common initial codes assigned to the data
# Out:
# Initial_Code
# Temporary accommodation      3
# Community referral           3
# Economic reliance            3
# Fear of consequences         2
# Limited accommodation        2
# Resource mobilisation        2
# Survivor-centred practice    2
# Community sensitisation      2
# Awareness campaigns          2
# Skills development           2
# Community reporting          2
# Entry point to services      1
# Police association           1
# Male survivor stigma         1
# Outdated training            1
# Lack of shelters             1
# Walk-in support only         1
# Hospital referrals           1
# Counselling                  1
# Specialist counselling       1
# Name: count, dtype: int64

# %%
df["Initial_Code"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Initial_Code'>

# %%
recommend = df["Recommendation"].value_counts()

recommend.plot(kind="barh")
# This shows the most common recommendations made by participants
# Out:
# <Axes: ylabel='Recommendation'>
